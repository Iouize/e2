# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.shape, test.shape
# Out:
# ((1235, 29), (824, 28))

# %%
train.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...  \
# 0                cool          reduced   dark_cyanotic  ...
# 1                cool           normal   pale_cyanotic  ...
# 2                cool          reduced       pale_pink  ...
# 3                cold          reduced       pale_pink  ...
# 4              normal           normal     normal_pink  ...
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               57.0           8.5     serosanguious            3.4
# 1               33.0          64.0     serosanguious            2.0
# 2               37.0           6.4     serosanguious            3.4
# 3               53.0           7.0            cloudy            3.9
# 4               47.0           7.3            cloudy            2.6
#
#   surgical_lesion lesion_1  lesion_2 lesion_3 cp_data     outcome
# 0             yes     2209         0        0      no        died
# 1             yes     2208         0        0      no  euthanized
# 2             yes     5124         0        0      no       lived
# 3             yes     2208         0        0     yes       lived
# 4              no        0         0        0     yes       lived
#
# [5 rows x 29 columns]

# %%
train.describe()
# Out:
#               id  hospital_number  rectal_temp        pulse  respiratory_rate  \
# count  1235.0000     1.235000e+03  1235.000000  1235.000000       1235.000000
# mean    617.0000     9.545004e+05    38.202186    79.574089         30.054251
# std     356.6581     1.356403e+06     0.788668    29.108638         16.452066
# min       0.0000     5.213990e+05    35.400000    30.000000          8.000000
# 25%     308.5000     5.288000e+05    37.800000    53.000000         18.000000
# 50%     617.0000     5.297770e+05    38.200000    76.000000         28.000000
# 75%     925.5000     5.341450e+05    38.600000   100.000000         36.000000
# max    1234.0000     5.305129e+06    40.800000   184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count            1235.000000         1235.000000    1235.000000
# mean                4.382591           49.602429      21.388016
# std                 1.937357           10.535800      26.676453
# min                 1.000000           23.000000       3.500000
# 25%                 2.000000           43.000000       6.600000
# 50%                 4.500000           48.000000       7.500000
# 75%                 6.000000           57.000000       9.100000
# max                 7.500000           75.000000      89.000000
#
#        abdomo_protein      lesion_1     lesion_2     lesion_3
# count     1235.000000   1235.000000  1235.000000  1235.000000
# mean         3.290931   3832.496356    14.612146     3.577328
# std          1.589195   5436.733774   193.705735    88.858953
# min          0.100000      0.000000     0.000000     0.000000
# 25%          2.000000   2205.000000     0.000000     0.000000
# 50%          3.000000   2209.000000     0.000000     0.000000
# 75%          4.300000   3205.000000     0.000000     0.000000
# max         10.100000  41110.000000  3112.000000  2209.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1235 non-null   int64
#  1   surgery                1235 non-null   object
#  2   age                    1235 non-null   object
#  3   hospital_number        1235 non-null   int64
#  4   rectal_temp            1235 non-null   float64
#  5   pulse                  1235 non-null   float64
#  6   respiratory_rate       1235 non-null   float64
#  7   temp_of_extremities    1196 non-null   object
#  8   peripheral_pulse       1175 non-null   object
#  9   mucous_membrane        1214 non-null   object
#  10  capillary_refill_time  1229 non-null   object
#  11  pain                   1191 non-null   object
#  12  peristalsis            1215 non-null   object
#  13  abdominal_distention   1212 non-null   object
#  14  nasogastric_tube       1155 non-null   object
#  15  nasogastric_reflux     1214 non-null   object
#  16  nasogastric_reflux_ph  1235 non-null   float64
#  17  rectal_exam_feces      1045 non-null   object
#  18  abdomen                1022 non-null   object
#  19  packed_cell_volume     1235 non-null   float64
#  20  total_protein          1235 non-null   float64
#  21  abdomo_appearance      1187 non-null   object
#  22  abdomo_protein         1235 non-null   float64
#  23  surgical_lesion        1235 non-null   object
#  24  lesion_1               1235 non-null   int64
#  25  lesion_2               1235 non-null   int64
#  26  lesion_3               1235 non-null   int64
#  27  cp_data                1235 non-null   object
#  28  outcome                1235 non-null   object
# dtypes: float64(7), int64(5), object(17)
# memory usage: 279.9+ KB

# %%
train['outcome'].value_counts()
# Out:
# outcome
# lived         574
# died          410
# euthanized    251
# Name: count, dtype: int64

# %% [markdown]
# Les classes ne sont pas homogènes

# %%
# Insérer visualisation

# %%
# Préprocessing

# %% [markdown]
# Il y a beaucoup de features catégorielles

# %%
train.isnull().sum()
# Out:
# id                         0
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp                0
# pulse                      0
# respiratory_rate           0
# temp_of_extremities       39
# peripheral_pulse          60
# mucous_membrane           21
# capillary_refill_time      6
# pain                      44
# peristalsis               20
# abdominal_distention      23
# nasogastric_tube          80
# nasogastric_reflux        21
# nasogastric_reflux_ph      0
# rectal_exam_feces        190
# abdomen                  213
# packed_cell_volume         0
# total_protein              0
# abdomo_appearance         48
# abdomo_protein             0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# outcome                    0
# dtype: int64

# %%
# Drop column id
train.drop('id',axis=1,inplace=True)
test.drop('id',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
target = train['outcome']
features = train.drop('outcome', axis=1)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
object_columns = train.select_dtypes(include='object').columns

# %%
categorical_features = []
for column in object_columns:
    categorical_features.append(train.columns.get_loc(column))

# %%
numeric_features = []

# %%
for column in train.columns:
    if train.columns.get_loc(column) not in categorical_features:
        numeric_features.append(train.columns.get_loc(column))

# %%
numeric_transformer = make_pipeline(StandardScaler())
categorical_transformer = make_pipeline(OneHotEncoder(handle_unknown="ignore"))

# %%
Preprocessor = ColumnTransformer(
    transformers=[
        ('numeric_transformer', numeric_transformer, numeric_features),
        ('categorical_transformer', categorical_transformer, categorical_features)
    ]
)

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_hist_gradient_boosting
# now you can import normally from ensemble
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
hgb_pipe = make_pipeline(Preprocessor, HistGradientBoostingClassifier())

# %%
seed = 42

# %%
categorical_features.remove(27)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 categorical_features.remove(27)
#
# ValueError: list.remove(x): x not in list

# %%
#parameters to tune
parameters = {
 'histgradientboostingclassifier__max_iter': [1000,1200,1500],
 'histgradientboostingclassifier__learning_rate': [0.1],
 'histgradientboostingclassifier__max_depth' : [25, 50, 75],
 'histgradientboostingclassifier__l2_regularization': [1.5],
 'histgradientboostingclassifier__scoring': ['f1_micro'],
 'histgradientboostingclassifier__random_state' : [seed],
 }
#instantiate the gridsearch
hgb_grid = GridSearchCV(hgb_pipe, parameters, n_jobs=5,
 cv=5, scoring='f1_micro',
 verbose=2, refit=True)

# %%
#fit on the grid
hgb_grid.fit(X_train2, y_train2)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.2s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.4s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  42.2s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  42.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  47.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  47.7s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  48.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.2s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.4s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=25, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  40.6s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  40.6s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.8s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.7s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.5s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  52.9s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  53.0s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  54.1s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  54.6s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  54.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=50, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  41.1s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  42.9s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  43.2s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1000, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  43.0s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.2s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.5s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.5s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1200, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  49.3s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time= 1.0min
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  56.6s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  56.4s
# [CV] END histgradientboostingclassifier__l2_regularization=1.5, histgradientboostingclassifier__learning_rate=0.1, histgradientboostingclassifier__max_depth=75, histgradientboostingclassifier__max_iter=1500, histgradientboostingclassifier__random_state=42, histgradientboostingclassifier__scoring=f1_micro; total time=  54.7s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('numeric_transformer',
#                                                                          Pipeline(steps=[('standardscaler',
#                                                                                           StandardScaler())]),
#                                                                          [2, 3,
#                                                                           4, 5,
#                                                                           15,
#                                                                           18,
#                                                                           19,
#                                                                           21,
#                                                                           23,
#                                                                           24,
#                                                                           25]),
#                                                                         ('categorical_transformer',
#                                                                          Pipeline(steps=[('onehotencoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          [0, 1,
#                                                                           6, 7,
#                                                                           8, 9,
#                                                                           10,
#                                                                           11,
#                                                                           12,
#                                                                           13,
#                                                                           14,
#                                                                           16,
#                                                                           17,
#                                                                           20,
#                                                                           22,
#                                                                           26...
#              param_grid={'histgradientboostingclassifier__l2_regularization': [1.5],
#                          'histgradientboostingclassifier__learning_rate': [0.1],
#                          'histgradientboostingclassifier__max_depth': [25, 50,
#                                                                        75],
#                          'histgradientboostingclassifier__max_iter': [1000,
#                                                                       1200,
#                                                                       1500],
#                          'histgradientboostingclassifier__random_state': [42],
#                          'histgradientboostingclassifier__scoring': ['f1_micro']},
#              scoring='f1_micro', verbose=2)

# %%
# Print the best parameters found
print(hgb_grid.best_params_)
# Print the best scores found
print()
print(hgb_grid.best_score_)
# Out:
# {'histgradientboostingclassifier__l2_regularization': 1.5, 'histgradientboostingclassifier__learning_rate': 0.1, 'histgradientboostingclassifier__max_depth': 25, 'histgradientboostingclassifier__max_iter': 1500, 'histgradientboostingclassifier__random_state': 42, 'histgradientboostingclassifier__scoring': 'f1_micro'}
#
# 0.702456032405271

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
#Predict on X_test and print the confusion matrix
print()
y_pred_hgb = hgb_grid.predict(X_test2)
print(confusion_matrix(y_test2, y_pred_hgb))
#Print the F1_score
print()
print(f1_score(y_test2, y_pred_hgb, average='micro'))
# Out:
# [[51  4 17]
#  [ 9 37  8]
#  [23  5 93]]
#
# 0.7327935222672065

# %%
import pprint

# %%
pprint.pp(hgb_grid.best_params_)
# Out:
# {'histgradientboostingclassifier__l2_regularization': 1.5,
#  'histgradientboostingclassifier__learning_rate': 0.1,
#  'histgradientboostingclassifier__max_depth': 25,
#  'histgradientboostingclassifier__max_iter': 1500,
#  'histgradientboostingclassifier__random_state': 42,
#  'histgradientboostingclassifier__scoring': 'f1_micro'}

# %%
submission_pred = hgb_grid.predict(test)

# %%
import pandas as pd

# %%
sub_df = pd.DataFrame(submission_pred)

# %%
sub_df
# Out:
#               0
# 0         lived
# 1         lived
# 2         lived
# 3    euthanized
# 4         lived
# ..          ...
# 819        died
# 820  euthanized
# 821        died
# 822       lived
# 823       lived
#
# [824 rows x 1 columns]

# %%
import csv

# %%
sub_df.to_csv('submission.csv')

# %%
test
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           534053         38.6   40.0              20.0
# 1       yes  adult           528469         38.2  112.0              48.0
# 2       yes  adult           528178         37.7   66.0              12.0
# 3        no  adult           534784         37.1   88.0              20.0
# 4       yes  adult           529840         38.3   50.0              12.0
# ..      ...    ...              ...          ...    ...               ...
# 819      no  adult           529461         40.3  114.0              36.0
# 820     yes  adult           535338         37.2  100.0              20.0
# 821     yes  adult           529640         39.2  132.0              12.0
# 822      no  adult          5287179         38.3   54.0              66.0
# 823     yes  adult           528461         38.1   66.0              12.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 0                normal           normal     normal_pink
# 1                  cool          reduced     bright_pink
# 2                  cool           normal      bright_red
# 3                  cool          reduced   pale_cyanotic
# 4                   NaN           normal     bright_pink
# ..                  ...              ...             ...
# 819                cool          reduced     normal_pink
# 820                cool          reduced   pale_cyanotic
# 821                cool          reduced   dark_cyanotic
# 822              normal           normal     normal_pink
# 823                cold           normal     normal_pink
#
#     capillary_refill_time  ...        abdomen packed_cell_volume  \
# 0              less_3_sec  ...  distend_small               42.0
# 1              more_3_sec  ...  distend_small               44.0
# 2              less_3_sec  ...  distend_small               31.5
# 3              less_3_sec  ...  distend_large               75.0
# 4              less_3_sec  ...  distend_small               37.0
# ..                    ...  ...            ...                ...
# 819            more_3_sec  ...  distend_large               57.0
# 820            more_3_sec  ...  distend_small               50.0
# 821            more_3_sec  ...            NaN               53.0
# 822            less_3_sec  ...            NaN               49.0
# 823            less_3_sec  ...  distend_small               31.5
#
#     total_protein abdomo_appearance abdomo_protein  surgical_lesion lesion_1  \
# 0             7.5             clear            2.3               no        0
# 1             6.0     serosanguious            2.6               no     2208
# 2             6.0            cloudy            1.6              yes     2205
# 3            81.0               NaN            1.0              yes     1400
# 4             6.8            cloudy            2.6              yes     2208
# ..            ...               ...            ...              ...      ...
# 819           8.1     serosanguious            4.5              yes     3205
# 820          66.0     serosanguious            2.0              yes     2209
# 821           7.6     serosanguious            4.5              yes     2205
# 822           8.6             clear            5.0               no     3111
# 823           6.2               NaN            1.6              yes     2205
#
#     lesion_2  lesion_3  cp_data
# 0          0         0       no
# 1          0         0      yes
# 2          0         0      yes
# 3          0         0       no
# 4          0         0      yes
# ..       ...       ...      ...
# 819        0         0      yes
# 820        0         0       no
# 821        0         0       no
# 822        0         0      yes
# 823        0         0      yes
#
# [824 rows x 27 columns]
